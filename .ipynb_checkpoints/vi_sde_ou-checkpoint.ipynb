# %%
import torch
from torch.autograd import Variable
from functorch import vmap
import matplotlib.pylab as plt
import numpy as np
import scipy.stats as ss

# %% [markdown]
# **Class: OU processes**

# %%
class OU:
    def __init__(self, t0, t1, z0, alpha, beta, sigma):
        self.t0 = t0
        self.t1 = t1
        self.z0 = z0
        self.alpha = alpha
        self.beta = beta
        self.sigma = sigma
        self.pts = torch.sort(torch.cat([torch.DoubleTensor(100).uniform_(t0,t1), torch.tensor([self.t0, self.t1])]))[0]
        self.trj, self.dt = self.simulate()
        
    def simulate(self):
        """
            Simulate an OU process on a set of discrete points
        """
        output = np.empty(len(self.pts))
        output[0] = self.z0
        interval = self.pts[1:] - self.pts[:-1]
        for t in range(1, len(self.pts)):
            
            # if the distance is too small, variance becomes 0
            dt = interval[t-1]
            
            mean = self.alpha + (output[t-1] - self.alpha) * np.exp(-1 * self.beta * dt)
            var = np.sqrt((self.sigma ** 2) * (1 - np.exp(-2 * self.beta * dt)) / (2 * self.beta))
            assert var > 0, "variance is negative, var:%.3f interval: %.3f" % (var, dt)
            output[t] = ss.norm.rvs(loc = mean, scale = var)
        return torch.from_numpy(output), interval

# %%
vi = OU(t0 = 0, t1 = 10., z0 = 2., alpha = 3., beta = 1., sigma = 1.)

# %%
plt.plot(vi.pts, vi.trj, 'rx')
plt.title("OU: alpha = %.2f" % vi.alpha + ", beta = %.2f" % vi.beta + ", sigma = %.2f" % vi.sigma)
plt.show()

# %% [markdown]
# Variational inference: KL

# %%
class ELBO:

    """
        Given a simulated variational process, compute the gradient of the ELBO. 
    """
    def __init__(self, ou):
        self.ou = ou
        self.alpha, self.beta, self.sigma = torch.tensor([ou.alpha, ou.beta, ou.sigma])
        
    def KL_ito(self):
        """
            1. Compute the Riemann approximation to integral in KL divergence
            
        """
        # Save parameter specification from ou class
        alpha, beta, sigma = self.alpha, self.beta, self.sigma

        # Obtain integral term (via Riemann approximation, e.g. trapezoid)
        func_kl = vmap(lambda z: 16*(z**6) - 32* (z**4) + (16-(beta**2) - 12*(sigma ** 2))*(z**2) + 2*alpha*(beta**2)*z)

        return torch.trapezoid(abs(func_kl(self.ou.trj)), x=self.ou.pts)
    
    def KL_rest(self):
        """
            2. Compute the rest
        """

        alpha, beta, sigma = self.alpha, self.beta, self.sigma
        z0 = self.ou.z0
        z1 = self.ou.trj[-1]
        t0 = self.ou.t0
        t1 = self.ou.t1
        
        # Obtain the rest 
        term1 = 1/(2*(sigma)**2) * (alpha**2 * beta**2 + (4+beta)*sigma**2) * (t1-t0)
    
        def A(u):
            return u**4 + ((4+beta) * u**2 / 2) - (alpha * beta * u)

        term2 = -1 / (sigma ** 2) * (A(z1) - A(z0))

        return term1 + term2
    
    def log_prob(self, obs):
        """
            Compute the log-likelihood
            likelihood function is normal density N(obs, var)
        """
        def log_pdf(obs, z):
            return ss.norm.logpdf(obs, loc=z, scale=.1)
            
        
        return log_pdf(obs, self.ou.trj[-1])

# %%
class Score:
    def __init__(self, ou):
        self.ou = ou
        
    def compute_score(self):
        """
            Compute the value of the score function at given parameters
            return a dictionary matching each parameter to its gradient
        """
        alpha, beta = Variable(torch.tensor([self.ou.alpha, self.ou.beta]), requires_grad=True)
        dt = self.ou.dt
        X = self.ou.trj
        
        def compute_transition(X, dt, alpha, beta, sigma):
            """
            Compute the transition density of the (simulated) path
            """
            term1 = -1/2 * (2 * torch.log(sigma) - torch.log(beta) + torch.log(1 - torch.exp(-2 * beta * dt)))
            term2 = -1 * beta * (X[1:] - alpha - (X[:-1] - alpha) * torch.exp(-1 * beta * dt)) ** 2 
            term3 = (sigma ** 2) * (1 - torch.exp(-2 * beta * dt))

            return torch.sum(term1 + term2/term3)
        
        NLL = compute_transition(X, dt, alpha, beta, torch.tensor(sigma))
        
        alpha.retain_grad()
        beta.retain_grad()
        
        NLL.backward()
        
        
#         return {'beta':beta.grad}
        return {'beta':beta.grad, 'alpha':alpha.grad}
#         return self.beta.grad

# %% [markdown]
# Noisy Observations from the SDE:
#
# $dX_{t} = 4X_{t}(1-X_{t})dt + \sigma dW_{t}$

# %%
# Time step the SDE: dot X = -mu X + sigma xi, by Euler's method.

# Problem setup. 
# Set model and numerical parameters, and the initial condition.
# These are the lines the user might want to vary.
tf = 100
Nsteps = 1000
Npaths = 1
X0 = 1
mu = 0.75
sigma = 0.5

# Generate the time grid and solution array
t, dt = np.linspace(0,tf,Nsteps+1,retstep=True)
X = np.zeros((Nsteps+1,Npaths))
root_dt = np.sqrt(dt)
  
# Time step starting from initial condition
X[0,:] = X0;
for n in range(Nsteps):
    F_of_X = 4 * X[n,:] * (1 - X[n,:])
    X[n+1,:] =  X[n,:] + dt * F_of_X + sigma * root_dt * np.random.randn(Npaths)

# Plot paths
plt.plot(t,X)
plt.plot(t[::100], X[::100], "rx")
plt.xlabel("t", fontsize=14)
plt.ylabel("X", fontsize=14)
plt.title("Sample paths", fontsize=14)
plt.show()

# %%
obs = np.random.normal(loc = X[::100], scale = .1)

# %%
plt.plot(t,X)
plt.plot(t[::100], obs, "rx")
plt.xlabel("t", fontsize=14)
plt.ylabel("X", fontsize=14)
plt.title("Noisy Observations", fontsize=14)
plt.show()

# %% [markdown]
# **Variational inference**

# %%
import tqdm as tq

# %%
alpha_ = 1.
beta_ = 2.

N = 100
learning_rate = 0.0002

# for i in tq.tqdm(range(300)):
for i in range(300):
    alpha_grad = 0.
    beta_grad = 0.

    for i in range(N):
        vi = OU(t0 = 0., t1 = 10., z0 = obs[0][0], alpha = alpha_ , beta = beta_ , sigma = .5)
        elbo = ELBO(vi)
        score = Score(vi)
        
        scores = score.compute_score()
        f_of_X = -1 * (elbo.log_prob(obs[1][0]) - (elbo.KL_ito() + elbo.KL_rest()))
        assert f_of_X != np.nan, "shit"

        alpha_grad += f_of_X * scores['alpha']
        beta_grad += f_of_X * scores['beta']
        
    alpha_ -= learning_rate * alpha_grad/N
    beta_ -= learning_rate * beta_grad/N
    
    print("alpha = ", alpha_, "beta = ", beta_)
# score.compute_score()
# Out:
# alpha =  tensor(0.9113, dtype=torch.float64) beta =  tensor(2.0057, dtype=torch.float64)
# alpha =  tensor(0.8531, dtype=torch.float64) beta =  tensor(2.0109, dtype=torch.float64)
# alpha =  tensor(0.8324, dtype=torch.float64) beta =  tensor(2.0153, dtype=torch.float64)
# alpha =  tensor(0.8454, dtype=torch.float64) beta =  tensor(2.0156, dtype=torch.float64)
# alpha =  tensor(0.8224, dtype=torch.float64) beta =  tensor(2.0202, dtype=torch.float64)
# alpha =  tensor(0.8550, dtype=torch.float64) beta =  tensor(2.0255, dtype=torch.float64)
# alpha =  tensor(0.8341, dtype=torch.float64) beta =  tensor(2.0309, dtype=torch.float64)
# alpha =  tensor(0.8160, dtype=torch.float64) beta =  tensor(2.0275, dtype=torch.float64)
# alpha =  tensor(0.7599, dtype=torch.float64) beta =  tensor(2.0308, dtype=torch.float64)
# alpha =  tensor(0.7728, dtype=torch.float64) beta =  tensor(2.0316, dtype=torch.float64)
# alpha =  tensor(0.8177, dtype=torch.float64) beta =  tensor(2.0324, dtype=torch.float64)
# alpha =  tensor(0.8172, dtype=torch.float64) beta =  tensor(2.0344, dtype=torch.float64)
# alpha =  tensor(0.8223, dtype=torch.float64) beta =  tensor(2.0356, dtype=torch.float64)
# alpha =  tensor(0.8070, dtype=torch.float64) beta =  tensor(2.0432, dtype=torch.float64)
# alpha =  tensor(0.7601, dtype=torch.float64) beta =  tensor(2.0494, dtype=torch.float64)
# alpha =  tensor(0.7602, dtype=torch.float64) beta =  tensor(2.0559, dtype=torch.float64)
# alpha =  tensor(0.7467, dtype=torch.float64) beta =  tensor(2.0542, dtype=torch.float64)
# alpha =  tensor(0.7527, dtype=torch.float64) beta =  tensor(2.0546, dtype=torch.float64)
# alpha =  tensor(0.7233, dtype=torch.float64) beta =  tensor(2.0612, dtype=torch.float64)
# alpha =  tensor(0.7348, dtype=torch.float64) beta =  tensor(2.0658, dtype=torch.float64)
# alpha =  tensor(0.7700, dtype=torch.float64) beta =  tensor(2.0707, dtype=torch.float64)
# alpha =  tensor(0.7674, dtype=torch.float64) beta =  tensor(2.0722, dtype=torch.float64)
# alpha =  tensor(0.8046, dtype=torch.float64) beta =  tensor(2.0747, dtype=torch.float64)
# alpha =  tensor(0.7512, dtype=torch.float64) beta =  tensor(2.0808, dtype=torch.float64)
# alpha =  tensor(0.7632, dtype=torch.float64) beta =  tensor(2.0768, dtype=torch.float64)
# alpha =  tensor(0.7427, dtype=torch.float64) beta =  tensor(2.0808, dtype=torch.float64)
# alpha =  tensor(0.7201, dtype=torch.float64) beta =  tensor(2.0817, dtype=torch.float64)
# alpha =  tensor(0.7056, dtype=torch.float64) beta =  tensor(2.0833, dtype=torch.float64)
# alpha =  tensor(0.7340, dtype=torch.float64) beta =  tensor(2.0847, dtype=torch.float64)
# alpha =  tensor(0.7708, dtype=torch.float64) beta =  tensor(2.0909, dtype=torch.float64)
# alpha =  tensor(0.7713, dtype=torch.float64) beta =  tensor(2.0899, dtype=torch.float64)
# alpha =  tensor(0.7341, dtype=torch.float64) beta =  tensor(2.0959, dtype=torch.float64)
# alpha =  tensor(0.7366, dtype=torch.float64) beta =  tensor(2.1007, dtype=torch.float64)
# alpha =  tensor(0.6861, dtype=torch.float64) beta =  tensor(2.1037, dtype=torch.float64)
# alpha =  tensor(0.6436, dtype=torch.float64) beta =  tensor(2.1060, dtype=torch.float64)
# alpha =  tensor(0.6262, dtype=torch.float64) beta =  tensor(2.1035, dtype=torch.float64)
# alpha =  tensor(0.6273, dtype=torch.float64) beta =  tensor(2.1018, dtype=torch.float64)
# alpha =  tensor(0.6169, dtype=torch.float64) beta =  tensor(2.0986, dtype=torch.float64)
# alpha =  tensor(0.6269, dtype=torch.float64) beta =  tensor(2.0981, dtype=torch.float64)
# alpha =  tensor(0.6217, dtype=torch.float64) beta =  tensor(2.1000, dtype=torch.float64)
# alpha =  tensor(0.6028, dtype=torch.float64) beta =  tensor(2.1012, dtype=torch.float64)
# alpha =  tensor(0.5964, dtype=torch.float64) beta =  tensor(2.1027, dtype=torch.float64)
# alpha =  tensor(0.6065, dtype=torch.float64) beta =  tensor(2.1044, dtype=torch.float64)
# alpha =  tensor(0.5687, dtype=torch.float64) beta =  tensor(2.0989, dtype=torch.float64)
# alpha =  tensor(0.5686, dtype=torch.float64) beta =  tensor(2.0996, dtype=torch.float64)
# alpha =  tensor(0.6012, dtype=torch.float64) beta =  tensor(2.0985, dtype=torch.float64)
# alpha =  tensor(0.6506, dtype=torch.float64) beta =  tensor(2.1007, dtype=torch.float64)
# alpha =  tensor(0.6738, dtype=torch.float64) beta =  tensor(2.0995, dtype=torch.float64)
# alpha =  tensor(0.6848, dtype=torch.float64) beta =  tensor(2.1029, dtype=torch.float64)
# alpha =  tensor(0.6812, dtype=torch.float64) beta =  tensor(2.1012, dtype=torch.float64)
# alpha =  tensor(0.7297, dtype=torch.float64) beta =  tensor(2.1040, dtype=torch.float64)
# alpha =  tensor(0.7104, dtype=torch.float64) beta =  tensor(2.1050, dtype=torch.float64)
# alpha =  tensor(0.7635, dtype=torch.float64) beta =  tensor(2.1071, dtype=torch.float64)
# alpha =  tensor(0.8016, dtype=torch.float64) beta =  tensor(2.1120, dtype=torch.float64)
# alpha =  tensor(0.7992, dtype=torch.float64) beta =  tensor(2.1091, dtype=torch.float64)
# alpha =  tensor(0.8234, dtype=torch.float64) beta =  tensor(2.1142, dtype=torch.float64)
# alpha =  tensor(0.7912, dtype=torch.float64) beta =  tensor(2.1139, dtype=torch.float64)
# alpha =  tensor(0.7687, dtype=torch.float64) beta =  tensor(2.1137, dtype=torch.float64)
# alpha =  tensor(0.7955, dtype=torch.float64) beta =  tensor(2.1156, dtype=torch.float64)
# alpha =  tensor(0.8450, dtype=torch.float64) beta =  tensor(2.1181, dtype=torch.float64)
# alpha =  tensor(0.8369, dtype=torch.float64) beta =  tensor(2.1184, dtype=torch.float64)
# alpha =  tensor(0.8551, dtype=torch.float64) beta =  tensor(2.1183, dtype=torch.float64)
# alpha =  tensor(0.8640, dtype=torch.float64) beta =  tensor(2.1212, dtype=torch.float64)
# alpha =  tensor(0.8204, dtype=torch.float64) beta =  tensor(2.1245, dtype=torch.float64)
# alpha =  tensor(0.8522, dtype=torch.float64) beta =  tensor(2.1279, dtype=torch.float64)
# alpha =  tensor(0.8773, dtype=torch.float64) beta =  tensor(2.1328, dtype=torch.float64)
# alpha =  tensor(0.8094, dtype=torch.float64) beta =  tensor(2.1343, dtype=torch.float64)
# alpha =  tensor(0.7565, dtype=torch.float64) beta =  tensor(2.1388, dtype=torch.float64)
# alpha =  tensor(0.7879, dtype=torch.float64) beta =  tensor(2.1364, dtype=torch.float64)
# alpha =  tensor(0.8243, dtype=torch.float64) beta =  tensor(2.1350, dtype=torch.float64)
# alpha =  tensor(0.8527, dtype=torch.float64) beta =  tensor(2.1340, dtype=torch.float64)
# alpha =  tensor(0.8305, dtype=torch.float64) beta =  tensor(2.1406, dtype=torch.float64)
# alpha =  tensor(0.8231, dtype=torch.float64) beta =  tensor(2.1450, dtype=torch.float64)
# alpha =  tensor(0.8129, dtype=torch.float64) beta =  tensor(2.1472, dtype=torch.float64)
# alpha =  tensor(0.7786, dtype=torch.float64) beta =  tensor(2.1513, dtype=torch.float64)
# alpha =  tensor(0.7590, dtype=torch.float64) beta =  tensor(2.1506, dtype=torch.float64)
# alpha =  tensor(0.7716, dtype=torch.float64) beta =  tensor(2.1501, dtype=torch.float64)
# alpha =  tensor(0.7580, dtype=torch.float64) beta =  tensor(2.1454, dtype=torch.float64)
# alpha =  tensor(0.7844, dtype=torch.float64) beta =  tensor(2.1411, dtype=torch.float64)
# alpha =  tensor(0.7981, dtype=torch.float64) beta =  tensor(2.1483, dtype=torch.float64)
# alpha =  tensor(0.7995, dtype=torch.float64) beta =  tensor(2.1449, dtype=torch.float64)
# alpha =  tensor(0.7743, dtype=torch.float64) beta =  tensor(2.1454, dtype=torch.float64)
# alpha =  tensor(0.8032, dtype=torch.float64) beta =  tensor(2.1432, dtype=torch.float64)
# alpha =  tensor(0.8117, dtype=torch.float64) beta =  tensor(2.1429, dtype=torch.float64)
# alpha =  tensor(0.8697, dtype=torch.float64) beta =  tensor(2.1468, dtype=torch.float64)
# alpha =  tensor(0.8628, dtype=torch.float64) beta =  tensor(2.1498, dtype=torch.float64)
# alpha =  tensor(0.8325, dtype=torch.float64) beta =  tensor(2.1598, dtype=torch.float64)
# alpha =  tensor(0.8799, dtype=torch.float64) beta =  tensor(2.1599, dtype=torch.float64)
# alpha =  tensor(0.8750, dtype=torch.float64) beta =  tensor(2.1559, dtype=torch.float64)
# alpha =  tensor(0.8236, dtype=torch.float64) beta =  tensor(2.1553, dtype=torch.float64)
# alpha =  tensor(0.7935, dtype=torch.float64) beta =  tensor(2.1585, dtype=torch.float64)
# alpha =  tensor(0.7880, dtype=torch.float64) beta =  tensor(2.1596, dtype=torch.float64)
# alpha =  tensor(0.7859, dtype=torch.float64) beta =  tensor(2.1504, dtype=torch.float64)
# alpha =  tensor(0.8191, dtype=torch.float64) beta =  tensor(2.1492, dtype=torch.float64)
# alpha =  tensor(0.8195, dtype=torch.float64) beta =  tensor(2.1509, dtype=torch.float64)
# alpha =  tensor(0.8273, dtype=torch.float64) beta =  tensor(2.1503, dtype=torch.float64)
# alpha =  tensor(0.8437, dtype=torch.float64) beta =  tensor(2.1487, dtype=torch.float64)
# alpha =  tensor(0.8532, dtype=torch.float64) beta =  tensor(2.1552, dtype=torch.float64)
# alpha =  tensor(0.8403, dtype=torch.float64) beta =  tensor(2.1625, dtype=torch.float64)
# alpha =  tensor(0.8480, dtype=torch.float64) beta =  tensor(2.1642, dtype=torch.float64)
# alpha =  tensor(0.8222, dtype=torch.float64) beta =  tensor(2.1667, dtype=torch.float64)
# alpha =  tensor(0.8677, dtype=torch.float64) beta =  tensor(2.1727, dtype=torch.float64)
# alpha =  tensor(0.8282, dtype=torch.float64) beta =  tensor(2.1761, dtype=torch.float64)
# alpha =  tensor(0.7854, dtype=torch.float64) beta =  tensor(2.1757, dtype=torch.float64)
# alpha =  tensor(0.8005, dtype=torch.float64) beta =  tensor(2.1806, dtype=torch.float64)
# alpha =  tensor(0.7930, dtype=torch.float64) beta =  tensor(2.1771, dtype=torch.float64)
# alpha =  tensor(0.7677, dtype=torch.float64) beta =  tensor(2.1753, dtype=torch.float64)
# alpha =  tensor(0.8469, dtype=torch.float64) beta =  tensor(2.1807, dtype=torch.float64)
# alpha =  tensor(0.8918, dtype=torch.float64) beta =  tensor(2.1843, dtype=torch.float64)
# alpha =  tensor(0.8184, dtype=torch.float64) beta =  tensor(2.1915, dtype=torch.float64)
# alpha =  tensor(0.8538, dtype=torch.float64) beta =  tensor(2.1946, dtype=torch.float64)
# alpha =  tensor(0.7948, dtype=torch.float64) beta =  tensor(2.1981, dtype=torch.float64)
# alpha =  tensor(0.7865, dtype=torch.float64) beta =  tensor(2.1964, dtype=torch.float64)
# alpha =  tensor(0.7588, dtype=torch.float64) beta =  tensor(2.2007, dtype=torch.float64)
# alpha =  tensor(0.7472, dtype=torch.float64) beta =  tensor(2.2011, dtype=torch.float64)
# alpha =  tensor(0.7503, dtype=torch.float64) beta =  tensor(2.2013, dtype=torch.float64)
# alpha =  tensor(0.7460, dtype=torch.float64) beta =  tensor(2.1991, dtype=torch.float64)
# alpha =  tensor(0.7476, dtype=torch.float64) beta =  tensor(2.2035, dtype=torch.float64)
# alpha =  tensor(0.7996, dtype=torch.float64) beta =  tensor(2.2064, dtype=torch.float64)
# alpha =  tensor(0.8499, dtype=torch.float64) beta =  tensor(2.2115, dtype=torch.float64)
# alpha =  tensor(0.8445, dtype=torch.float64) beta =  tensor(2.2149, dtype=torch.float64)
# alpha =  tensor(0.8715, dtype=torch.float64) beta =  tensor(2.2169, dtype=torch.float64)
# alpha =  tensor(0.8464, dtype=torch.float64) beta =  tensor(2.2182, dtype=torch.float64)
# alpha =  tensor(0.8141, dtype=torch.float64) beta =  tensor(2.2338, dtype=torch.float64)
# alpha =  tensor(0.7787, dtype=torch.float64) beta =  tensor(2.2375, dtype=torch.float64)
# alpha =  tensor(0.8143, dtype=torch.float64) beta =  tensor(2.2340, dtype=torch.float64)
# alpha =  tensor(0.7967, dtype=torch.float64) beta =  tensor(2.2408, dtype=torch.float64)
# alpha =  tensor(0.8080, dtype=torch.float64) beta =  tensor(2.2481, dtype=torch.float64)
# alpha =  tensor(0.8802, dtype=torch.float64) beta =  tensor(2.2476, dtype=torch.float64)
# alpha =  tensor(0.9092, dtype=torch.float64) beta =  tensor(2.2538, dtype=torch.float64)
# alpha =  tensor(0.9010, dtype=torch.float64) beta =  tensor(2.2511, dtype=torch.float64)
# alpha =  tensor(0.9702, dtype=torch.float64) beta =  tensor(2.2523, dtype=torch.float64)
# alpha =  tensor(0.8568, dtype=torch.float64) beta =  tensor(2.2631, dtype=torch.float64)
# alpha =  tensor(0.7865, dtype=torch.float64) beta =  tensor(2.2694, dtype=torch.float64)
# alpha =  tensor(0.7853, dtype=torch.float64) beta =  tensor(2.2713, dtype=torch.float64)
# alpha =  tensor(0.7398, dtype=torch.float64) beta =  tensor(2.2709, dtype=torch.float64)
# alpha =  tensor(0.7512, dtype=torch.float64) beta =  tensor(2.2747, dtype=torch.float64)
# alpha =  tensor(0.7970, dtype=torch.float64) beta =  tensor(2.2765, dtype=torch.float64)
# alpha =  tensor(0.8318, dtype=torch.float64) beta =  tensor(2.2719, dtype=torch.float64)
# alpha =  tensor(0.7650, dtype=torch.float64) beta =  tensor(2.2721, dtype=torch.float64)
# alpha =  tensor(0.7605, dtype=torch.float64) beta =  tensor(2.2808, dtype=torch.float64)
# alpha =  tensor(0.7751, dtype=torch.float64) beta =  tensor(2.2816, dtype=torch.float64)
# alpha =  tensor(0.7916, dtype=torch.float64) beta =  tensor(2.2793, dtype=torch.float64)
# alpha =  tensor(0.8366, dtype=torch.float64) beta =  tensor(2.2816, dtype=torch.float64)
# alpha =  tensor(0.8400, dtype=torch.float64) beta =  tensor(2.2874, dtype=torch.float64)
# alpha =  tensor(0.8694, dtype=torch.float64) beta =  tensor(2.2903, dtype=torch.float64)
# alpha =  tensor(0.8277, dtype=torch.float64) beta =  tensor(2.2892, dtype=torch.float64)
# alpha =  tensor(0.8039, dtype=torch.float64) beta =  tensor(2.2829, dtype=torch.float64)
# alpha =  tensor(0.8059, dtype=torch.float64) beta =  tensor(2.2738, dtype=torch.float64)
# alpha =  tensor(0.8751, dtype=torch.float64) beta =  tensor(2.2718, dtype=torch.float64)
# alpha =  tensor(0.7942, dtype=torch.float64) beta =  tensor(2.2792, dtype=torch.float64)
# alpha =  tensor(0.8331, dtype=torch.float64) beta =  tensor(2.2859, dtype=torch.float64)
# alpha =  tensor(0.7681, dtype=torch.float64) beta =  tensor(2.2923, dtype=torch.float64)
# alpha =  tensor(0.7203, dtype=torch.float64) beta =  tensor(2.2942, dtype=torch.float64)
# alpha =  tensor(0.7128, dtype=torch.float64) beta =  tensor(2.2949, dtype=torch.float64)
# alpha =  tensor(0.7437, dtype=torch.float64) beta =  tensor(2.2904, dtype=torch.float64)
# alpha =  tensor(0.7918, dtype=torch.float64) beta =  tensor(2.2864, dtype=torch.float64)
# alpha =  tensor(0.7990, dtype=torch.float64) beta =  tensor(2.2873, dtype=torch.float64)
# alpha =  tensor(0.7780, dtype=torch.float64) beta =  tensor(2.2820, dtype=torch.float64)
# alpha =  tensor(0.7471, dtype=torch.float64) beta =  tensor(2.2811, dtype=torch.float64)
# alpha =  tensor(0.7380, dtype=torch.float64) beta =  tensor(2.2829, dtype=torch.float64)
# alpha =  tensor(0.7601, dtype=torch.float64) beta =  tensor(2.2858, dtype=torch.float64)
# alpha =  tensor(0.7380, dtype=torch.float64) beta =  tensor(2.2818, dtype=torch.float64)
# alpha =  tensor(0.8203, dtype=torch.float64) beta =  tensor(2.2887, dtype=torch.float64)
# alpha =  tensor(0.8263, dtype=torch.float64) beta =  tensor(2.2966, dtype=torch.float64)
# alpha =  tensor(0.8543, dtype=torch.float64) beta =  tensor(2.2990, dtype=torch.float64)
# alpha =  tensor(0.8127, dtype=torch.float64) beta =  tensor(2.3049, dtype=torch.float64)
# alpha =  tensor(0.8298, dtype=torch.float64) beta =  tensor(2.2984, dtype=torch.float64)
# alpha =  tensor(0.8080, dtype=torch.float64) beta =  tensor(2.2991, dtype=torch.float64)
# alpha =  tensor(0.8481, dtype=torch.float64) beta =  tensor(2.3016, dtype=torch.float64)
# alpha =  tensor(0.8316, dtype=torch.float64) beta =  tensor(2.3052, dtype=torch.float64)
# alpha =  tensor(0.8234, dtype=torch.float64) beta =  tensor(2.3143, dtype=torch.float64)
# alpha =  tensor(0.7191, dtype=torch.float64) beta =  tensor(2.3151, dtype=torch.float64)
# alpha =  tensor(0.7536, dtype=torch.float64) beta =  tensor(2.3144, dtype=torch.float64)
# alpha =  tensor(0.7418, dtype=torch.float64) beta =  tensor(2.3183, dtype=torch.float64)
# alpha =  tensor(0.7079, dtype=torch.float64) beta =  tensor(2.3169, dtype=torch.float64)
# alpha =  tensor(0.6600, dtype=torch.float64) beta =  tensor(2.3178, dtype=torch.float64)
# alpha =  tensor(0.6458, dtype=torch.float64) beta =  tensor(2.3140, dtype=torch.float64)
# alpha =  tensor(0.6244, dtype=torch.float64) beta =  tensor(2.3130, dtype=torch.float64)
# alpha =  tensor(0.6415, dtype=torch.float64) beta =  tensor(2.3090, dtype=torch.float64)
# alpha =  tensor(0.6659, dtype=torch.float64) beta =  tensor(2.3023, dtype=torch.float64)
# alpha =  tensor(0.7000, dtype=torch.float64) beta =  tensor(2.2975, dtype=torch.float64)
# alpha =  tensor(0.6953, dtype=torch.float64) beta =  tensor(2.2970, dtype=torch.float64)
# alpha =  tensor(0.6843, dtype=torch.float64) beta =  tensor(2.2934, dtype=torch.float64)
# alpha =  tensor(0.7191, dtype=torch.float64) beta =  tensor(2.2914, dtype=torch.float64)
# alpha =  tensor(0.6973, dtype=torch.float64) beta =  tensor(2.2894, dtype=torch.float64)
# alpha =  tensor(0.7073, dtype=torch.float64) beta =  tensor(2.2886, dtype=torch.float64)
# alpha =  tensor(0.7104, dtype=torch.float64) beta =  tensor(2.2841, dtype=torch.float64)
# alpha =  tensor(0.6814, dtype=torch.float64) beta =  tensor(2.2900, dtype=torch.float64)
# alpha =  tensor(0.7375, dtype=torch.float64) beta =  tensor(2.2942, dtype=torch.float64)
# alpha =  tensor(0.7266, dtype=torch.float64) beta =  tensor(2.2931, dtype=torch.float64)
# alpha =  tensor(0.6972, dtype=torch.float64) beta =  tensor(2.2926, dtype=torch.float64)
# alpha =  tensor(0.6987, dtype=torch.float64) beta =  tensor(2.2904, dtype=torch.float64)
# alpha =  tensor(0.7360, dtype=torch.float64) beta =  tensor(2.2906, dtype=torch.float64)
# alpha =  tensor(0.7706, dtype=torch.float64) beta =  tensor(2.2917, dtype=torch.float64)
# alpha =  tensor(0.7855, dtype=torch.float64) beta =  tensor(2.2907, dtype=torch.float64)
# alpha =  tensor(0.8081, dtype=torch.float64) beta =  tensor(2.2930, dtype=torch.float64)
# alpha =  tensor(0.8008, dtype=torch.float64) beta =  tensor(2.2954, dtype=torch.float64)
# alpha =  tensor(0.7771, dtype=torch.float64) beta =  tensor(2.2978, dtype=torch.float64)
# alpha =  tensor(0.7765, dtype=torch.float64) beta =  tensor(2.2959, dtype=torch.float64)
# alpha =  tensor(0.7530, dtype=torch.float64) beta =  tensor(2.2963, dtype=torch.float64)
# alpha =  tensor(0.8112, dtype=torch.float64) beta =  tensor(2.2956, dtype=torch.float64)
# alpha =  tensor(0.8160, dtype=torch.float64) beta =  tensor(2.3034, dtype=torch.float64)
# alpha =  tensor(0.8004, dtype=torch.float64) beta =  tensor(2.3078, dtype=torch.float64)
# alpha =  tensor(0.8313, dtype=torch.float64) beta =  tensor(2.3071, dtype=torch.float64)
# alpha =  tensor(0.8689, dtype=torch.float64) beta =  tensor(2.3078, dtype=torch.float64)
# alpha =  tensor(0.9207, dtype=torch.float64) beta =  tensor(2.3140, dtype=torch.float64)
# alpha =  tensor(0.8668, dtype=torch.float64) beta =  tensor(2.3251, dtype=torch.float64)
# alpha =  tensor(0.8775, dtype=torch.float64) beta =  tensor(2.3231, dtype=torch.float64)
# alpha =  tensor(0.8683, dtype=torch.float64) beta =  tensor(2.3215, dtype=torch.float64)
# alpha =  tensor(0.8573, dtype=torch.float64) beta =  tensor(2.3190, dtype=torch.float64)
# alpha =  tensor(0.8199, dtype=torch.float64) beta =  tensor(2.3194, dtype=torch.float64)
# alpha =  tensor(0.8955, dtype=torch.float64) beta =  tensor(2.3181, dtype=torch.float64)
# alpha =  tensor(0.9728, dtype=torch.float64) beta =  tensor(2.3212, dtype=torch.float64)
# alpha =  tensor(0.9819, dtype=torch.float64) beta =  tensor(2.3189, dtype=torch.float64)
# alpha =  tensor(0.9184, dtype=torch.float64) beta =  tensor(2.3314, dtype=torch.float64)
# alpha =  tensor(0.8758, dtype=torch.float64) beta =  tensor(2.3376, dtype=torch.float64)
# alpha =  tensor(0.8233, dtype=torch.float64) beta =  tensor(2.3347, dtype=torch.float64)
# alpha =  tensor(0.7745, dtype=torch.float64) beta =  tensor(2.3336, dtype=torch.float64)
# alpha =  tensor(0.7932, dtype=torch.float64) beta =  tensor(2.3345, dtype=torch.float64)
# alpha =  tensor(0.8105, dtype=torch.float64) beta =  tensor(2.3327, dtype=torch.float64)
# alpha =  tensor(0.7835, dtype=torch.float64) beta =  tensor(2.3318, dtype=torch.float64)
# alpha =  tensor(0.7293, dtype=torch.float64) beta =  tensor(2.3335, dtype=torch.float64)
# alpha =  tensor(0.7536, dtype=torch.float64) beta =  tensor(2.3279, dtype=torch.float64)
# alpha =  tensor(0.7106, dtype=torch.float64) beta =  tensor(2.3299, dtype=torch.float64)
# alpha =  tensor(0.7053, dtype=torch.float64) beta =  tensor(2.3324, dtype=torch.float64)
# alpha =  tensor(0.7176, dtype=torch.float64) beta =  tensor(2.3332, dtype=torch.float64)
# alpha =  tensor(0.6791, dtype=torch.float64) beta =  tensor(2.3339, dtype=torch.float64)
# alpha =  tensor(0.7241, dtype=torch.float64) beta =  tensor(2.3313, dtype=torch.float64)
# alpha =  tensor(0.7321, dtype=torch.float64) beta =  tensor(2.3339, dtype=torch.float64)
# alpha =  tensor(0.7565, dtype=torch.float64) beta =  tensor(2.3403, dtype=torch.float64)
# alpha =  tensor(0.7609, dtype=torch.float64) beta =  tensor(2.3445, dtype=torch.float64)
# alpha =  tensor(0.7471, dtype=torch.float64) beta =  tensor(2.3479, dtype=torch.float64)
# alpha =  tensor(0.6931, dtype=torch.float64) beta =  tensor(2.3440, dtype=torch.float64)
# alpha =  tensor(0.6277, dtype=torch.float64) beta =  tensor(2.3470, dtype=torch.float64)
# alpha =  tensor(0.6351, dtype=torch.float64) beta =  tensor(2.3486, dtype=torch.float64)
# alpha =  tensor(0.5778, dtype=torch.float64) beta =  tensor(2.3530, dtype=torch.float64)
# alpha =  tensor(0.5883, dtype=torch.float64) beta =  tensor(2.3551, dtype=torch.float64)
# alpha =  tensor(0.5831, dtype=torch.float64) beta =  tensor(2.3534, dtype=torch.float64)
# alpha =  tensor(0.6049, dtype=torch.float64) beta =  tensor(2.3521, dtype=torch.float64)
# alpha =  tensor(0.5786, dtype=torch.float64) beta =  tensor(2.3536, dtype=torch.float64)
# alpha =  tensor(0.5533, dtype=torch.float64) beta =  tensor(2.3509, dtype=torch.float64)
# alpha =  tensor(0.5859, dtype=torch.float64) beta =  tensor(2.3482, dtype=torch.float64)
# alpha =  tensor(0.6345, dtype=torch.float64) beta =  tensor(2.3475, dtype=torch.float64)
# alpha =  tensor(0.6111, dtype=torch.float64) beta =  tensor(2.3493, dtype=torch.float64)
# alpha =  tensor(0.6089, dtype=torch.float64) beta =  tensor(2.3517, dtype=torch.float64)
# alpha =  tensor(0.6099, dtype=torch.float64) beta =  tensor(2.3481, dtype=torch.float64)
# alpha =  tensor(0.5693, dtype=torch.float64) beta =  tensor(2.3451, dtype=torch.float64)
# alpha =  tensor(0.5766, dtype=torch.float64) beta =  tensor(2.3404, dtype=torch.float64)
# alpha =  tensor(0.6106, dtype=torch.float64) beta =  tensor(2.3396, dtype=torch.float64)
# alpha =  tensor(0.5977, dtype=torch.float64) beta =  tensor(2.3423, dtype=torch.float64)
# alpha =  tensor(0.5562, dtype=torch.float64) beta =  tensor(2.3454, dtype=torch.float64)
# alpha =  tensor(0.5634, dtype=torch.float64) beta =  tensor(2.3420, dtype=torch.float64)
# alpha =  tensor(0.6059, dtype=torch.float64) beta =  tensor(2.3410, dtype=torch.float64)
# alpha =  tensor(0.6505, dtype=torch.float64) beta =  tensor(2.3429, dtype=torch.float64)
# alpha =  tensor(0.7481, dtype=torch.float64) beta =  tensor(2.3428, dtype=torch.float64)
# alpha =  tensor(0.7789, dtype=torch.float64) beta =  tensor(2.3398, dtype=torch.float64)
# alpha =  tensor(0.8108, dtype=torch.float64) beta =  tensor(2.3401, dtype=torch.float64)
# alpha =  tensor(0.8233, dtype=torch.float64) beta =  tensor(2.3416, dtype=torch.float64)
# alpha =  tensor(0.8367, dtype=torch.float64) beta =  tensor(2.3370, dtype=torch.float64)
# alpha =  tensor(0.8604, dtype=torch.float64) beta =  tensor(2.3362, dtype=torch.float64)
# alpha =  tensor(0.7412, dtype=torch.float64) beta =  tensor(2.3446, dtype=torch.float64)
# alpha =  tensor(0.7980, dtype=torch.float64) beta =  tensor(2.3433, dtype=torch.float64)
# alpha =  tensor(0.8296, dtype=torch.float64) beta =  tensor(2.3431, dtype=torch.float64)
# alpha =  tensor(0.8055, dtype=torch.float64) beta =  tensor(2.3393, dtype=torch.float64)
# alpha =  tensor(0.8030, dtype=torch.float64) beta =  tensor(2.3414, dtype=torch.float64)
# alpha =  tensor(0.7461, dtype=torch.float64) beta =  tensor(2.3435, dtype=torch.float64)
# alpha =  tensor(0.7976, dtype=torch.float64) beta =  tensor(2.3504, dtype=torch.float64)
# alpha =  tensor(0.6648, dtype=torch.float64) beta =  tensor(2.3555, dtype=torch.float64)
# alpha =  tensor(0.6618, dtype=torch.float64) beta =  tensor(2.3588, dtype=torch.float64)
# alpha =  tensor(0.7024, dtype=torch.float64) beta =  tensor(2.3623, dtype=torch.float64)
# alpha =  tensor(0.7201, dtype=torch.float64) beta =  tensor(2.3643, dtype=torch.float64)
# alpha =  tensor(0.6440, dtype=torch.float64) beta =  tensor(2.3672, dtype=torch.float64)
# alpha =  tensor(0.6622, dtype=torch.float64) beta =  tensor(2.3667, dtype=torch.float64)
# alpha =  tensor(0.7021, dtype=torch.float64) beta =  tensor(2.3669, dtype=torch.float64)
# alpha =  tensor(0.7354, dtype=torch.float64) beta =  tensor(2.3618, dtype=torch.float64)
# alpha =  tensor(0.7205, dtype=torch.float64) beta =  tensor(2.3570, dtype=torch.float64)
# alpha =  tensor(0.7231, dtype=torch.float64) beta =  tensor(2.3590, dtype=torch.float64)
# alpha =  tensor(0.7371, dtype=torch.float64) beta =  tensor(2.3559, dtype=torch.float64)
# alpha =  tensor(0.6967, dtype=torch.float64) beta =  tensor(2.3488, dtype=torch.float64)
# alpha =  tensor(0.6863, dtype=torch.float64) beta =  tensor(2.3503, dtype=torch.float64)
# alpha =  tensor(0.7188, dtype=torch.float64) beta =  tensor(2.3541, dtype=torch.float64)
# alpha =  tensor(0.7108, dtype=torch.float64) beta =  tensor(2.3545, dtype=torch.float64)
# alpha =  tensor(0.7116, dtype=torch.float64) beta =  tensor(2.3558, dtype=torch.float64)
# alpha =  tensor(0.6853, dtype=torch.float64) beta =  tensor(2.3603, dtype=torch.float64)
# alpha =  tensor(0.7080, dtype=torch.float64) beta =  tensor(2.3541, dtype=torch.float64)
# alpha =  tensor(0.7342, dtype=torch.float64) beta =  tensor(2.3548, dtype=torch.float64)
# alpha =  tensor(0.7351, dtype=torch.float64) beta =  tensor(2.3501, dtype=torch.float64)
# alpha =  tensor(0.7536, dtype=torch.float64) beta =  tensor(2.3510, dtype=torch.float64)
# alpha =  tensor(0.8380, dtype=torch.float64) beta =  tensor(2.3466, dtype=torch.float64)
# alpha =  tensor(0.8388, dtype=torch.float64) beta =  tensor(2.3459, dtype=torch.float64)
# alpha =  tensor(0.8506, dtype=torch.float64) beta =  tensor(2.3489, dtype=torch.float64)
# alpha =  tensor(0.8555, dtype=torch.float64) beta =  tensor(2.3586, dtype=torch.float64)
# alpha =  tensor(0.9223, dtype=torch.float64) beta =  tensor(2.3620, dtype=torch.float64)
# alpha =  tensor(0.9195, dtype=torch.float64) beta =  tensor(2.3679, dtype=torch.float64)
# alpha =  tensor(0.9008, dtype=torch.float64) beta =  tensor(2.3673, dtype=torch.float64)
# alpha =  tensor(0.8135, dtype=torch.float64) beta =  tensor(2.3759, dtype=torch.float64)
# alpha =  tensor(0.7535, dtype=torch.float64) beta =  tensor(2.3783, dtype=torch.float64)
# alpha =  tensor(0.7489, dtype=torch.float64) beta =  tensor(2.3769, dtype=torch.float64)
# alpha =  tensor(0.7371, dtype=torch.float64) beta =  tensor(2.3778, dtype=torch.float64)

# %%
f_of_X
# Out:
# tensor(135.3654, dtype=torch.float64)

# %%
for i in range(10):
    posterior = OU(t0 = 0., t1 = 1., z0 = obs[0][0], alpha = alpha_ , beta = beta_ , sigma = .5)
    plt.plot(posterior.pts, posterior.trj, 'b')
    plt.plot(obs, 'rx')
plt.plot(t,X, 'grey', linestyle='dashed')

# %%
for i in range(50):
    posterior = OU(t0 = 0., t1 = 1., z0 = obs[0][0], alpha = alpha_, beta = -0.2, sigma = .5)
    plt.plot(posterior.pts, posterior.trj, 'b')
    plt.plot(obs[:2], 'rx')
plt.plot(t[:100],X[:100], 'grey', linestyle='dashed')

# %%
alpha_, beta_, obs[0]
# Out:
# (tensor(0.7371, dtype=torch.float64),
#  tensor(2.3778, dtype=torch.float64),
#  array([0.85333505]))

# %%
# observations at t1 vs posterior mean at t1
obs[1], alpha_ + (torch.from_numpy(obs[0]) - alpha_)*torch.exp(-1 * beta_ * 1)
# Out:
# (array([0.86422779]), tensor([0.7479], dtype=torch.float64))

# %%
def posterior_moment(init, alpha, beta):
    pts = np.linspace(0,1,100)
    dt = pts[1:] - pts[:-1]
    
    mean = [init]
        
    for i in range(dt.shape[0]):
        mean.append(alpha + (mean[i] - alpha)*np.exp(-1 * beta * dt[i]))
    
    func = lambda t: np.sqrt((alpha ** 2 / (2*beta)) * (1 - np.exp(-2 * beta * t)))
    sd = list(map(func, dt))
    
    return np.array(mean), np.array(sd)

# %%
pmean, psd = posterior_moment(obs[0][0], alpha_.data.numpy(), beta_.data.numpy())

# %%
plt.plot(t[:100], X[:100])
plt.plot(t[:100], pmean)
# plt.fill_between(t[1:100], pmean[1:] - psd, pmean[1:] + psd)

# %%
plt.plot(t[:100], pmean)
plt.plot(obs[:2], 'rx')

# %%
def KL_ito(z0, alpha, beta, sigma):
    """
        Compute the Riemann approximation to integral in KL divergence
    """
    func_kl = vmap(lambda z: 16*(z**6) - 32* (z**4) + (16-(beta**2) - 12*(sigma ** 2))*(z**2) + 2*alpha*(beta**2)*z)
    
    # select 100 random points between 0 and 1 while including 1 by default
    loc, _ = torch.sort(torch.cat([torch.FloatTensor(100).uniform_(0,1), torch.tensor([1.])]))
    x, delta = simulate_OU_v4(z0, alpha, beta, sigma, loc)
    
    return torch.trapezoid(abs(func_kl(x)), x=loc)

# %%
def KL_rest(t0, t1, z0, z1, alpha, beta, sigma):
    term1 = 1/(2*(sigma)**2) * (alpha**2 * beta**2 + (4+beta)*sigma**2) * (t1-t0)
    
    def A(u):
        return u**4 + ((4+beta) * u**2 / 2) - (alpha * beta * u)
    
    term2 = -1 / (sigma ** 2) * (A(z1) - A(z0))
    
    return term1 + term2
